# %% [markdown]
# ### MountainCar Using Q-Learning- Here, intention is to move on top the flag pole and then stay on the flag spot until the end of the episode-with Q-learning

# %%
# import necessary libraries module
import gymnasium as gym
import numpy as np
import os
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# #### Creating the Agent environment

# %%
# make the env
# Again, it can seen that there is issue 
# of inability to adapt to random starting conditions
# which could be handled by a training learned policy.
# It actually started at a position -0.44
# then to like -0.51 after 3 trials
env = gym.make("MountainCar-v0", render_mode='rgb_array')

# visualize the environment
env.reset()
plt.imshow(env.render())

# %%
# observation space
# the position is between -1.2 to 0.6
# the velocity is between -0.07 to 0.07
env.observation_space
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %% [markdown]
# #### Need to create the bins for the position and velocity

# %%
# helper variables
# Here, I started 30 and 20 to see
# how better the accuracy works out
num_position_bins = 50
num_velocity_bins = 30

# for calculating the needed steps in the bins
max_position = env.observation_space.high[0]
min_position = env.observation_space.low[0]
max_velocity = env.observation_space.high[1]
min_velocity = env.observation_space.low[1]

# create the bins for position and velocity separately
# first step, create the ranges between the bins by using LINSPACE
position_bins = np.linspace(min_position, max_position, num_position_bins)
velocity_bins = np.linspace(min_velocity, max_velocity, num_velocity_bins)

# second step, use NumPy's digitize in order to discretize our state space
# positions = np.digitize(position_bins, bins=position_bins) - 1
# velocities = np.digitize(velocity_bins, bins=velocity_bins) - 1

# %%
max_position, min_velocity
# Out:
# (np.float32(0.6), np.float32(-0.07))

# %%
max_velocity, min_velocity
# Out:
# (np.float32(0.07), np.float32(-0.07))

# %%
# how many states will we have in total
num_states = num_position_bins * num_velocity_bins
print(f"Number of possible states in Q-table: {num_states}")
# Out:
# Number of possible states in Q-table: 1500

# %% [markdown]
# #### Here, I created the Q-table with the help of the bins

# %%
# create the Q-table
Q_table = np.zeros((num_position_bins, num_velocity_bins, env.action_space.n))
Q_table.shape
# Out:
# (50, 30, 3)

# %% [markdown]
# #### Creating a helper function that update the Q-table

# %%
# The Q-table update the function that stores 
# both position and velocity values
# (the index values have to match in both)
def calculate_value(Q, state, action, reward, next_state, alpha, gamma):
    # keeping both position and velocity values
    # state[0] = position, state[1] = velocity
    Q[state[0], state[1], action] = Q[state[0], state[1], action] + alpha * (reward + gamma * np.max(Q[next_state[0], next_state[1]]) - Q[state[0], state[1], action])
    return Q

# %%
# A helper function => as the environment gives all the observations
# (velocity and positions) in the original format, and then discretize the 
# position and velocity instantly.
# This maps the real values into the bins
# for example: 30 for position, 20 for velocity which are 
# the correct bin for both position and velocity
def get_state(observation):
    position = np.digitize(observation[0], bins=position_bins) - 1
    velocity = np.digitize(observation[1], bins=velocity_bins) - 1
    return position, velocity

# %% [markdown]
# ### The New Hyperparameters

# %%
# total training episodes, in this case, 15000 should do
total_episodes = 30000

# this environment is probably solvable in 100-200 steps
max_steps = 400

# learning rate => 0.2 (to make milder updates)
# you can experiment probably between 0.1 and 0.5
learning_rate = 0.2

# The need to encourage long term reward 
# because we only wish our car to get past the flag
gamma = 0.99

# exploration parameters
epsilon = 0.9

# upper bound of our epsilon
max_epsilon = 0.9

# this is the lower bound, and our code is not going to decay the epsilon below this
# we can actually disable the whole epsilon in this case in the end
min_epsilon = 0.001

# ramping up the decay rate for faster switch to using the
# Q-table instead of guessing too much
decay_rate = 0.00025

# %% [markdown]
# ### The training Agent model loop- Q-learning

# %%
# for visualizing our reward progress while training
rewards = []

# "play" the game for the amount episodes defined
for episode in range(total_episodes):
    # get initial state
    state, info = env.reset()

    # And the state (current, old, new)
    # are discretize it with functions
    state = get_state(state)

    # in the beginning of the game, the game is not over
    # the game is done either by falling into a hole or finding the goal
    done = False

    # in the beginning of the game, total_rewards are 0
    total_rewards = 0

    # Here, the game started playing 
    for step in range(max_steps):

        # exploration/exploitation
        if np.random.uniform(0, 1) > epsilon:
            # use exploitation in this case => use best known action for this cell!
            # fix this to use correct format
            action = np.argmax(Q_table[state[0], state[1]])
        else:
            # let's explore => random action
            action = env.action_space.sample()

        # gtinget the results from the action done from above
        # and unpack the results into: observation, reward, done
        new_state, reward, done, truncated, info = env.step(action)

        # get the current state
        position = new_state[0]

        # convert the current observation into our bins
        new_state = get_state(new_state)

        # let's see if we have solved the environment => we have driven past the flag
        if done and position >= 0.5:
            reward = 150
            Q_table = calculate_value(Q_table, state, action, reward, new_state, learning_rate, gamma)
            total_rewards += reward
            print(f"Episode {episode} done, steps needed {step}, rewards: {total_rewards}, epsilon: {epsilon}")
            break

        # This then update the Q-table with the values we have right now
        Q_table = calculate_value(Q_table, state, action, reward, new_state, learning_rate, gamma)

        # saving the current state and update rewards
        state = new_state
        total_rewards = total_rewards + reward

    # for visualization purposes, let's collect the rewards into a list
    rewards.append(total_rewards)        

    # Then, apply decay to epsilon
    # instead of linear decay, we have an expontential curve
    epsilon = min_epsilon + (max_epsilon - min_epsilon) * np.exp(-decay_rate * episode)
# Out:
# Episode 650 done, steps needed 350, rewards: -200.0, epsilon: 0.7653555301110408
# Episode 785 done, steps needed 373, rewards: -223.0, epsilon: 0.7399889989756897
# Episode 793 done, steps needed 313, rewards: -163.0, epsilon: 0.7385124979709101
# Episode 826 done, steps needed 350, rewards: -200.0, epsilon: 0.732453049456169
# Episode 878 done, steps needed 317, rewards: -167.0, epsilon: 0.7230057006303943
# Episode 950 done, steps needed 354, rewards: -204.0, epsilon: 0.7101258642997261
# Episode 958 done, steps needed 357, rewards: -207.0, epsilon: 0.7087090298778267
# Episode 959 done, steps needed 360, rewards: -210.0, epsilon: 0.7085321247344216
# Episode 1053 done, steps needed 321, rewards: -171.0, epsilon: 0.6920989656827331
# Episode 1060 done, steps needed 327, rewards: -177.0, epsilon: 0.6908906001210398
# Episode 1064 done, steps needed 324, rewards: -174.0, epsilon: 0.6902010543512658
# Episode 1072 done, steps needed 270, rewards: -120.0, epsilon: 0.6888240297261965
# Episode 1073 done, steps needed 370, rewards: -220.0, epsilon: 0.6886520952114747
# Episode 1075 done, steps needed 371, rewards: -221.0, epsilon: 0.6883083551060566
# Episode 1091 done, steps needed 279, rewards: -129.0, epsilon: 0.6855646128285096
# Episode 1099 done, steps needed 336, rewards: -186.0, epsilon: 0.6841968518197815
# Episode 1324 done, steps needed 285, rewards: -135.0, epsilon: 0.6468278837579726
# Episode 1326 done, steps needed 322, rewards: -172.0, epsilon: 0.646505050531126
# Episode 1327 done, steps needed 394, rewards: -244.0, epsilon: 0.6463436944388452
# Episode 1328 done, steps needed 376, rewards: -226.0, epsilon: 0.6461823786805454
# Episode 1336 done, steps needed 376, rewards: -226.0, epsilon: 0.6448933034281285
# Episode 1338 done, steps needed 357, rewards: -207.0, epsilon: 0.6445714372496646
# Episode 1344 done, steps needed 365, rewards: -215.0, epsilon: 0.6436068037497837
# Episode 1345 done, steps needed 331, rewards: -181.0, epsilon: 0.6434461721286355
# Episode 1348 done, steps needed 393, rewards: -243.0, epsilon: 0.6429645181423616
# Episode 1353 done, steps needed 326, rewards: -176.0, epsilon: 0.6421625638205557
# Episode 1359 done, steps needed 335, rewards: -185.0, epsilon: 0.6412015409221905
# Episode 1360 done, steps needed 334, rewards: -184.0, epsilon: 0.6410415105415911
# Episode 1363 done, steps needed 257, rewards: -107.0, epsilon: 0.6405616593753651
# Episode 1365 done, steps needed 365, rewards: -215.0, epsilon: 0.6402419584775624
# Episode 1367 done, steps needed 371, rewards: -221.0, epsilon: 0.6399224173902525
# Episode 1371 done, steps needed 253, rewards: -103.0, epsilon: 0.6392838143276105
# Episode 1374 done, steps needed 319, rewards: -169.0, epsilon: 0.6388052809393167
# Episode 1379 done, steps needed 335, rewards: -185.0, epsilon: 0.6380085224159643
# Episode 1386 done, steps needed 335, rewards: -185.0, epsilon: 0.6368947323522905
# Episode 1388 done, steps needed 362, rewards: -212.0, epsilon: 0.6365768644597097
# Episode 1400 done, steps needed 260, rewards: -110.0, epsilon: 0.6346729911042686
# Episode 1402 done, steps needed 316, rewards: -166.0, epsilon: 0.6343562338046405
# Episode 1408 done, steps needed 356, rewards: -206.0, epsilon: 0.6334069116235672
# Episode 1410 done, steps needed 308, rewards: -158.0, epsilon: 0.6330907872054459
# Episode 1422 done, steps needed 365, rewards: -215.0, epsilon: 0.6311973564100954
# Episode 1424 done, steps needed 370, rewards: -220.0, epsilon: 0.6308823364934325
# Episode 1425 done, steps needed 320, rewards: -170.0, epsilon: 0.6307248855914919
# Episode 1427 done, steps needed 324, rewards: -174.0, epsilon: 0.6304101018511892
# Episode 1431 done, steps needed 327, rewards: -177.0, epsilon: 0.6297810063495135
# Episode 1439 done, steps needed 373, rewards: -223.0, epsilon: 0.6285247010608715
# Episode 1442 done, steps needed 338, rewards: -188.0, epsilon: 0.6280542339822835
# Episode 1445 done, steps needed 320, rewards: -170.0, epsilon: 0.6275841196217186
# Episode 1446 done, steps needed 264, rewards: -114.0, epsilon: 0.6274274931709353
# Episode 1452 done, steps needed 323, rewards: -173.0, epsilon: 0.6264885563098753
# Episode 1454 done, steps needed 319, rewards: -169.0, epsilon: 0.6261758902047606
# Episode 1457 done, steps needed 388, rewards: -238.0, epsilon: 0.6257071840738767
# Episode 1460 done, steps needed 334, rewards: -184.0, epsilon: 0.6252388293408003
# Episode 1462 done, steps needed 304, rewards: -154.0, epsilon: 0.6249267879429802
# Episode 3346 done, steps needed 354, rewards: -204.0, epsilon: 0.39056589696184807
# Episode 3351 done, steps needed 364, rewards: -214.0, epsilon: 0.3900792438122305
# Episode 3353 done, steps needed 360, rewards: -210.0, epsilon: 0.3898847528171251
# Episode 3354 done, steps needed 256, rewards: -106.0, epsilon: 0.3897875437805567
# Episode 3360 done, steps needed 263, rewards: -113.0, epsilon: 0.3892047996322616
# Episode 3361 done, steps needed 344, rewards: -194.0, epsilon: 0.3891077605627427
# Episode 3368 done, steps needed 309, rewards: -159.0, epsilon: 0.3884291659252486
# Episode 3373 done, steps needed 388, rewards: -238.0, epsilon: 0.3879451820208011
# Episode 3375 done, steps needed 249, rewards: -99.0, epsilon: 0.3877517577898781
# Episode 3379 done, steps needed 389, rewards: -239.0, epsilon: 0.3873651993435246
# Episode 3408 done, steps needed 341, rewards: -191.0, epsilon: 0.3845741813138713
# Episode 3409 done, steps needed 346, rewards: -196.0, epsilon: 0.3844782997542372
# Episode 3415 done, steps needed 352, rewards: -202.0, epsilon: 0.3839035135020673
# Episode 3421 done, steps needed 384, rewards: -234.0, epsilon: 0.38332958878296447
# Episode 3425 done, steps needed 274, rewards: -124.0, epsilon: 0.38294745029527016
# Episode 3456 done, steps needed 325, rewards: -175.0, epsilon: 0.3799987983404095
# Episode 3461 done, steps needed 399, rewards: -249.0, epsilon: 0.37952534581196173
# Episode 3462 done, steps needed 276, rewards: -126.0, epsilon: 0.3794307263034401
# Episode 3467 done, steps needed 291, rewards: -141.0, epsilon: 0.3789579834214171
# Episode 3470 done, steps needed 337, rewards: -187.0, epsilon: 0.37867462120796375
# Episode 3475 done, steps needed 250, rewards: -100.0, epsilon: 0.37820282286684903
# Episode 3476 done, steps needed 366, rewards: -216.0, epsilon: 0.3781085339477383
# Episode 3478 done, steps needed 383, rewards: -233.0, epsilon: 0.37792002681147574
# Episode 3479 done, steps needed 251, rewards: -101.0, epsilon: 0.37782580858254217
# Episode 3490 done, steps needed 253, rewards: -103.0, epsilon: 0.3767909611762932
# Episode 3498 done, steps needed 347, rewards: -197.0, epsilon: 0.3760401303350588
# Episode 3513 done, steps needed 301, rewards: -151.0, epsilon: 0.37463636355405544
# Episode 3514 done, steps needed 259, rewards: -109.0, epsilon: 0.37454296613833044
# Episode 3516 done, steps needed 327, rewards: -177.0, epsilon: 0.3743562413403508
# Episode 3526 done, steps needed 379, rewards: -229.0, epsilon: 0.3734240165035796
# Episode 3528 done, steps needed 288, rewards: -138.0, epsilon: 0.373237851040572
# Episode 3531 done, steps needed 384, rewards: -234.0, epsilon: 0.37295877731801913
# Episode 3532 done, steps needed 365, rewards: -215.0, epsilon: 0.3728657992464328
# Episode 3536 done, steps needed 254, rewards: -104.0, epsilon: 0.3724941193181239
# Episode 3537 done, steps needed 368, rewards: -218.0, epsilon: 0.3724012573965182
# Episode 3539 done, steps needed 392, rewards: -242.0, epsilon: 0.37221560318524055
# Episode 3541 done, steps needed 330, rewards: -180.0, epsilon: 0.3720300417778657
# Episode 3542 done, steps needed 399, rewards: -249.0, epsilon: 0.3719372958611438
# Episode 29992 done, steps needed 177, rewards: -27.0, epsilon: 0.0014983428597124327
# Episode 29993 done, steps needed 178, rewards: -28.0, epsilon: 0.001498218289569421
# Episode 29994 done, steps needed 223, rewards: -73.0, epsilon: 0.0014980937505650526
# Episode 29995 done, steps needed 170, rewards: -20.0, epsilon: 0.0014979692426915444
# Episode 29996 done, steps needed 283, rewards: -133.0, epsilon: 0.0014978447659411134
# Episode 29997 done, steps needed 185, rewards: -35.0, epsilon: 0.0014977203203059807
# Episode 29998 done, steps needed 160, rewards: -10.0, epsilon: 0.0014975959057783683
# Episode 29999 done, steps needed 181, rewards: -31.0, epsilon: 0.0014974715223504999

# %%
# let's see the rewards progression
plt.plot(rewards)
plt.show()

# %% [markdown]
# #### Pretty obvious the Agent model learnt absolute nothing for the 1 minute plus and started learning after 4100 plus total episodes. And can seen that it learnt then stop learning at every few total episodes. However, towards the end the Agent model could be seen pretty well learning.

# %% [markdown]
# ### Quite flunctuating every now and then I think

# %%
 # convert the rewards -list into NumPy -array format
rewards_arr = np.array(rewards)

# define a window size for a moving average

# 50 is okay for 15000 episodes as the minimum window size
# if the running mean line is too noisy, adjust the window size
# rule of thumb: many episodes => bigger window_ize
# 15000 => 30-50 is okay for window size
window_size = 50

# normalize the rewards (manual MinMax -normalization)
normalized_rewards = (rewards_arr - min(rewards_arr)) / (max(rewards_arr) - min(rewards_arr))

# calculate the running mean
running_mean = np.convolve(normalized_rewards, np.ones(window_size) / window_size, mode="valid")

# visualize rewards + RUNNING MEAN
plt.plot(normalized_rewards)
plt.plot(running_mean)
plt.show()

# %% [markdown]
# ##Now, the Agent is trained to play and park the car past the flag

# %%
# let's use now the Q-table (agent) we have for this environment
# => play the game based on the Q-table but only using exploitation

total_test_episodes = 3

env.reset()
clear_output(wait=True)
plt.imshow(env.render())
plt.show()

# for-loop => allow the agent to play this 5 times in a row (5 episodes)
for episode in range(total_test_episodes):
    state, info = env.reset()
    state = get_state(state)
    done = False
    total_rewards = 0

    # play for the max number of steps
    for step in range(max_steps):
        # take the best action for this situation from the Q-table
        # basically based on the current cell => choose the best action we have calculated
        # in the Q-table during training

        # an idea for the exercise project:
        # => if multiple identical high values => choose a random path
        action = np.argmax(Q_table[state[0], state[1]])

        # unpack the results
        observation, reward, done, truncated, info = env.step(action)
        observation = get_state(observation)

        # update total rewards
        total_rewards = total_rewards + reward

        # update the visual frame
        clear_output(wait=True)
        plt.imshow(env.render())
        plt.show()

        # if we are game over either by hole or goal => break the loop
        if done:
            print(f"Episode: {episode + 1} done with total_rewards: {total_rewards}")
            time.sleep(2)
            break

        # save new state as old state, continue with next step
        state = observation
        # time.sleep(0.3)

env.close()
# Out:
# Episode: 3 done with total_rewards: -185.0

# %% [markdown]
# ### My observation:
#
# ### I think the much bins made the agent to learn by exploring less and highly exploiting the past experience which makes it accuracy effective and efficiently as it updating the Q-values through the states.
# ### I would say, optimizing the hyperparameters (changing the values) and the policy that had successfully made the rewards encouraging which then had made the RL Agent to be highly efficient.
