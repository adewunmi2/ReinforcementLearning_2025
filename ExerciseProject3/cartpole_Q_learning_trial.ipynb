# %% [markdown]
# ###  Cart Pole - here, using the Classical Q-learning -trial.......

# %%
# import necessary modules
import gymnasium as gym
import numpy as np
import os
import time
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# #### Creating the Cartpole environment

# %%
# Creating the game env
env = gym.make("CartPole-v1", render_mode='rgb_array')

# visualize the environment
env.reset()
plt.imshow(env.render())

# %%
# Here, setting the env boundaries
# to say -5 -> +5
env.observation_space
# Out:
# Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)

# %% [markdown]
# #### Above showed that the environment is a continuous space with shape (4,)- state here is a 4D vector. The range are lower bounds: [-4.8, -inf, -0.41887903, -inf] and upper bounds: [ 4.8, inf, 0.41887903, inf].
# #### The values representation:
# #### Cart Position (min: -4.8, max: 4.8)
#
# #### Cart Velocity (unbounded)
#
# #### Pole Angle (min: -0.418 rad ≈ -24°, max: 0.418 rad ≈ 24°)
#
# #### Pole Angular Velocity (unbounded)

# %% [markdown]
# ####  https://gymnasium.farama.org/environments/classic_control/cart_pole/

# %%
# helper variables
# Need to adjust the amount of bins for better accuracy
# NB: the more bins the heavier agent to train (more memory needed also)
num_cart_position_bins = 30
num_cart_velocity_bins = 30
num_pole_angle_bins = 20
num_pole_angular_velocity_bins = 20

# for calculating the needed steps in the bins
max_cart_position = env.observation_space.high[0]
min_cart_position = env.observation_space.low[0]
max_cart_velocity = 5
min_cart_velocity = -5
max_pole_angle = env.observation_space.high[2]
min_pole_angle = env.observation_space.low[2]
max_pole_angular_velocity = 5
min_pole_angular_velocity = -5

# created the bins for position and velocity separately
# creating the ranges between the bins by using LINSPACE
cart_position_bins = np.linspace(min_cart_position, max_cart_position, num_cart_position_bins)
cart_velocity_bins = np.linspace(min_cart_velocity, max_cart_velocity, num_cart_velocity_bins)
pole_angle_bins = np.linspace(min_pole_angle, max_pole_angle, num_pole_angle_bins)
pole_angular_velocity_bins = np.linspace(min_pole_angular_velocity, max_pole_angular_velocity, num_pole_angular_velocity_bins)

# This calculate the number of states total in our Q-table
# with just 20-30 bins per observation variable
# the Q-table will be having 360000 states 
# then real size is doubled
num_states = num_cart_position_bins * num_cart_velocity_bins * num_pole_angle_bins * num_pole_angular_velocity_bins
print(f"Number of possible states based on the observation bins: {num_states}")

# finally, create an empty Q-table
Q_table = np.zeros((num_cart_position_bins, num_cart_velocity_bins, num_pole_angle_bins, num_pole_angular_velocity_bins, env.action_space.n))
# Out:
# Number of possible states based on the observation bins: 360000

# %%
# double-check the shape that it matches the bins + actions
Q_table.shape
# Out:
# (30, 30, 20, 20, 2)

# %%
# this has to now match 4 observations.... quite impractical
def calculate_value(Q, state, action, reward, next_state, alpha, gamma):
    # we need to accomodate both position and velocity
    # state[0] = cart position, state[1] = cart velocity, state[2] = pole angle, state[3] = pole angular velocity 
    Q[state[0], state[1], state[2], state[3], action] += alpha * (reward + gamma * np.max(Q[next_state[0], next_state[1], next_state[2], next_state[3]]) - Q[state[0], state[1], state[2], state[3], action])
    return Q

# %%
 # this also has to now match 4 observations
def get_state(observation):
    cart_position = np.digitize(observation[0], bins=cart_position_bins) - 1
    cart_velocity = np.digitize(observation[1], bins=cart_velocity_bins) - 1
    pole_angle = np.digitize(observation[2], bins=pole_angle_bins) - 1
    pole_angular_velocity = np.digitize(observation[3], bins=pole_angular_velocity_bins) - 1
    return cart_position, cart_velocity, pole_angle, pole_angular_velocity

# %% [markdown]
# ### The Hyperparameters

# %%
# hyperparameters, see earlier Q-learning examples for explanations of each
# probably need to adjust these a bit after trying the training loop out
total_episodes = 50000
max_steps = 500
learning_rate = 0.5
gamma = 0.9
epsilon = 0.99
max_epsilon = 0.99
min_epsilon = 0.01
# decay_rate = 0.0003
decay_rate = 0.9995

# rule of thumb for the decay rate:
# use exponential decay if minimum epsilon is not part of an exit condition
# in the training loop
# if minimum epsilon is part of the exit condition => use linear decay (like in DQN)

# %% [markdown]
# #### The Q-Learning training loop

# %%
# training loop here
# for visualizing our reward progress while training
rewards = []

# "play" the game for the amount episodes defined
for episode in range(total_episodes):
    # get initial state
    state, info = env.reset()

    # every time you handle any kind of state (current, old, new)
    # you have to discretize it with your functions
    state = get_state(state)

    # from the beginning of the game, it shows the game is not over
    # the game is done either by falling into a hole or finding the goal
    done = False

    # in the beginning of the game, and total_rewards are 0
    total_rewards = 0

    # start playing the game in this episode
    for step in range(max_steps):

        # PHASE 1: exploration/exploitation
        if np.random.uniform(0, 1) > epsilon:
            # use exploitation in this case => use best known action for this cell!
            # fix this to use correct format
            action = np.argmax(Q_table[state[0], state[1], state[2], state[3]])
        else:
            # let's explore => random action
            action = env.action_space.sample()

        # Then the result is gotten from the action done
        # and unpack the results into: observation, reward, done
        new_state, reward, done, truncated, info = env.step(action)

        # convert the current observation into our bins
        new_state = get_state(new_state)

        # let's see if we have solved the environment => we have driven past the flag
        if done:
            reward = -100
        

        # update the Q-table with the values we have right now
        Q_table = calculate_value(Q_table, state, action, reward, new_state, learning_rate, gamma)

        # save current state and update rewards
        state = new_state
        total_rewards = total_rewards + reward

        # game over -> stop proceeding further
        if done:
            break

    # for visualization purposes, let's collect the rewards into a list
    rewards.append(total_rewards)        

    # applying the decay to epsilon
    # instead of linear decay, however have an expontential curve
    # epsilon = min_epsilon + (max_epsilon - min_epsilon) * np.exp(-decay_rate * episode)
    epsilon = max(min_epsilon, epsilon * decay_rate)

    print(f"Episode {episode} done, steps needed {step}, rewards: {total_rewards}, epsilon: {epsilon}")            

    # if epsilon is minimum and total rewards are almost maxed out => stop training
    # technically this is our "EarlyStop" -mechanism, you can use a more elaborate version if you need
    if epsilon == min_epsilon and total_rewards >= max_steps - 5:
        break
# Out:
# Episode 0 done, steps needed 10, rewards: -90.0, epsilon: 0.9895050000000001
# Episode 1 done, steps needed 23, rewards: -77.0, epsilon: 0.9890102475000001
# Episode 2 done, steps needed 15, rewards: -85.0, epsilon: 0.9885157423762502
# Episode 3 done, steps needed 16, rewards: -84.0, epsilon: 0.9880214845050621
# Episode 496 done, steps needed 21, rewards: -79.0, epsilon: 0.7721221766501828
# Episode 497 done, steps needed 31, rewards: -69.0, epsilon: 0.7717361155618577
# Episode 498 done, steps needed 36, rewards: -64.0, epsilon: 0.7713502475040769
# Episode 499 done, steps needed 26, rewards: -74.0, epsilon: 0.7709645723803249
# Episode 500 done, steps needed 38, rewards: -62.0, epsilon: 0.7705790900941347
# Episode 501 done, steps needed 17, rewards: -83.0, epsilon: 0.7701938005490877
# Episode 502 done, steps needed 28, rewards: -72.0, epsilon: 0.7698087036488132
# Episode 503 done, steps needed 20, rewards: -80.0, epsilon: 0.7694237992969888
# Episode 504 done, steps needed 68, rewards: -32.0, epsilon: 0.7690390873973403
# Episode 505 done, steps needed 24, rewards: -76.0, epsilon: 0.7686545678536416
# Episode 506 done, steps needed 33, rewards: -67.0, epsilon: 0.7682702405697148
# Episode 507 done, steps needed 111, rewards: 11.0, epsilon: 0.76788610544943
# Episode 508 done, steps needed 29, rewards: -71.0, epsilon: 0.7675021623967053
# Episode 509 done, steps needed 31, rewards: -69.0, epsilon: 0.7671184113155071
# Episode 510 done, steps needed 36, rewards: -64.0, epsilon: 0.7667348521098494
# Episode 511 done, steps needed 51, rewards: -49.0, epsilon: 0.7663514846837944
# Episode 512 done, steps needed 18, rewards: -82.0, epsilon: 0.7659683089414526
# Episode 513 done, steps needed 21, rewards: -79.0, epsilon: 0.7655853247869819
# Episode 514 done, steps needed 16, rewards: -84.0, epsilon: 0.7652025321245884
# Episode 515 done, steps needed 86, rewards: -14.0, epsilon: 0.7648199308585262
# Episode 516 done, steps needed 18, rewards: -82.0, epsilon: 0.7644375208930969
# Episode 517 done, steps needed 14, rewards: -86.0, epsilon: 0.7640553021326504
# Episode 518 done, steps needed 29, rewards: -71.0, epsilon: 0.7636732744815841
# Episode 519 done, steps needed 53, rewards: -47.0, epsilon: 0.7632914378443433
# Episode 520 done, steps needed 31, rewards: -69.0, epsilon: 0.7629097921254212
# Episode 521 done, steps needed 71, rewards: -29.0, epsilon: 0.7625283372293585
# Episode 522 done, steps needed 60, rewards: -40.0, epsilon: 0.7621470730607439
# Episode 523 done, steps needed 25, rewards: -75.0, epsilon: 0.7617659995242135
# Episode 524 done, steps needed 49, rewards: -51.0, epsilon: 0.7613851165244515
# Episode 525 done, steps needed 27, rewards: -73.0, epsilon: 0.7610044239661893
# Episode 526 done, steps needed 34, rewards: -66.0, epsilon: 0.7606239217542062
# Episode 527 done, steps needed 36, rewards: -64.0, epsilon: 0.7602436097933292
# Episode 528 done, steps needed 32, rewards: -68.0, epsilon: 0.7598634879884325
# Episode 529 done, steps needed 29, rewards: -71.0, epsilon: 0.7594835562444383
# Episode 530 done, steps needed 11, rewards: -89.0, epsilon: 0.7591038144663161
# Episode 531 done, steps needed 9, rewards: -91.0, epsilon: 0.758724262559083
# Episode 532 done, steps needed 37, rewards: -63.0, epsilon: 0.7583449004278034
# Episode 533 done, steps needed 26, rewards: -74.0, epsilon: 0.7579657279775895
# Episode 9187 done, steps needed 286, rewards: 186.0, epsilon: 0.01
# Episode 9188 done, steps needed 304, rewards: 204.0, epsilon: 0.01
# Episode 9189 done, steps needed 290, rewards: 190.0, epsilon: 0.01
# Episode 9190 done, steps needed 205, rewards: 105.0, epsilon: 0.01
# Episode 9191 done, steps needed 176, rewards: 76.0, epsilon: 0.01
# Episode 9192 done, steps needed 379, rewards: 279.0, epsilon: 0.01
# Episode 9193 done, steps needed 266, rewards: 166.0, epsilon: 0.01
# Episode 9194 done, steps needed 196, rewards: 96.0, epsilon: 0.01
# Episode 9195 done, steps needed 203, rewards: 103.0, epsilon: 0.01
# Episode 9196 done, steps needed 289, rewards: 189.0, epsilon: 0.01
# Episode 9197 done, steps needed 310, rewards: 210.0, epsilon: 0.01
# Episode 9198 done, steps needed 499, rewards: 500.0, epsilon: 0.01

# %% [markdown]
# #### The training started with low rewards and high exploration (epsilon near 1), reflecting poor performance. Over time, rewards increased steadily while epsilon decayed to 0.01, showing reduced exploration and better policy learning. By episode 9192, the agent achieved a perfect score of 500 as the epsilon decreases, indicating successful Q-learning convergence and the ability to balance the pole for nearly the maximum steps.

# %%
# convert the rewards -list into NumPy -array format
rewards_arr = np.array(rewards)

# define a window size for a moving average

# 50 is okay for 15000 episodes as the minimum window size
# NB: if the running mean line is too noisy, adjust the window size
# rule of thumb: many episodes => bigger window_ize
# 15000 => 30-50 is okay for window size
window_size = 200

# normalize the rewards (manual MinMax -normalization)
normalized_rewards = (rewards_arr - min(rewards_arr)) / (max(rewards_arr) - min(rewards_arr))

# calculate the running mean
running_mean = np.convolve(normalized_rewards, np.ones(window_size) / window_size, mode="valid")

print("Rewards w/ running mean:")
# visualize rewards + RUNNING MEAN
plt.plot(normalized_rewards)
plt.plot(running_mean)
plt.show()
# Out:
# Rewards w/ running mean:

# %% [markdown]
# #### It can be seen that the agent model started learning right from the beginning of the training process. Although there is slight flunctuation on couple of times but not that significant and the model surge up high again.

# %% [markdown]
# #### Test the agent in the environment

# %%
# test the agent in the environment
# make a new environment for the test
env = gym.make("CartPole-v1", render_mode="rgb_array")
state, info = env.reset()
state = get_state(state)
total_reward = 0

# play the environment
for step in range(1000):
    # action = select_action(state, epsilon)
    action = np.argmax(Q_table[state[0], state[1], state[2], state[3]])
    state, reward, done, truncated, info = env.step(action)
    state = get_state(state)
    total_reward += reward

    # visualize frame
    clear_output(wait=True)
    plt.imshow(env.render())
    plt.show()

    if done:
        break

# print result
print(f"Total Reward: {total_reward}")
env.close()
# Playing the game will show effective 
# and eeficient the game plays out
# Out:
# Total Reward: 1000.0

# %% [markdown]
# #### After testing the trained Agent to balance the Cartpole at different attempt I noticed the that Cartpole tried to balance between the range 300 to 350. And when it moved to the right it did not balance often as it always tilted its anglular position to the right howver, often balance when moving to the left.
# #### At the end of the first attempt, it didn't balance properly while it moved to the left and the second attempt it did try balance at least better off than the first attempt.
# #### NB: I forgot to take the snapshot for the first attempt but below is the image for the second attempt.
#
# ![image.png](attachment:image.png)
