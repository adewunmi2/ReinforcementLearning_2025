# %% [markdown]
# ### Here, I used PPO- CnnPolicy

# %%
# the usual thing with GPT code -> fix the ale_py import 
import gymnasium as gym
import ale_py
gym.register_envs(ale_py)

# import stable baselines => PPO as the base algorithm
# Dummy vector environment => handles image data
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import time

# %%
class SurvivalAssaultWrapper(gym.Wrapper):
    def __init__(self, env):
        super().__init__(env)
        self.time_alive = 0  

    def step(self, action):
        obs, reward, done, trunc, info = self.env.step(action)
        self.time_alive += 1
        reward = 0.1  # Small survival reward per step
        return obs, reward, done, trunc, info
    
# Create environment with video recording
env = gym.make("AssaultNoFrameskip-v4", render_mode="rgb_array")  # Ensure RGB mode
env = SurvivalAssaultWrapper(env)

# %%
# Initialize PPO model, CnnPolicy is most likely better in 
# Atari environments than the basic MlpPolicy
model = PPO('CnnPolicy', env, verbose=1)

# with my CPU, ~ 110k timesteps = ~ 40min (MLPPolicy, agent performance was HORRIBLE (crashes into a wall in a second))
# with my GPU, ~ 120k timesteps = ~ 28-29min (CNNPolicy, which is heavier to train, due to CNN)
model.learn(total_timesteps=500000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.94e+03 |
# |    ep_rew_mean     | 194      |
# | time/              |          |
# |    fps             | 67       |
# |    iterations      | 1        |
# |    time_elapsed    | 30       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.94e+03    |
# |    ep_rew_mean          | 194         |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 2           |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016151395 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.516      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0371     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 0.0799      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.33e+03    |
# |    ep_rew_mean          | 233         |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 3           |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.048668943 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.91       |
# |    explained_variance   | -0.143      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.119      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0733     |
# |    value_loss           | 0.0381      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.24e+03    |
# |    ep_rew_mean          | 224         |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 4           |
# |    time_elapsed         | 704         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.048564717 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.111      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0657     |
# |    value_loss           | 0.0577      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 5           |
# |    time_elapsed         | 915         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.059314877 |
# |    clip_fraction        | 0.498       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.85       |
# |    explained_variance   | 0.574       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0646     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0776     |
# |    value_loss           | 0.0436      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.88e+03    |
# |    ep_rew_mean          | 188         |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 6           |
# |    time_elapsed         | 1124        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.055905923 |
# |    clip_fraction        | 0.467       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.569       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0747     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0714     |
# |    value_loss           | 0.061       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.92e+03   |
# |    ep_rew_mean          | 192        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 7          |
# |    time_elapsed         | 1337       |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.07674145 |
# |    clip_fraction        | 0.509      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | 0.542      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.135     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0825    |
# |    value_loss           | 0.0539     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.92e+03    |
# |    ep_rew_mean          | 192         |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 8           |
# |    time_elapsed         | 1568        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.087437645 |
# |    clip_fraction        | 0.563       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.13       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0961     |
# |    value_loss           | 0.0433      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.96e+03   |
# |    ep_rew_mean          | 196        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 9          |
# |    time_elapsed         | 1781       |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.08541091 |
# |    clip_fraction        | 0.577      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.72      |
# |    explained_variance   | 0.712      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.108     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.087     |
# |    value_loss           | 0.0378     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.01e+03   |
# |    ep_rew_mean          | 201        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 10         |
# |    time_elapsed         | 1987       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.09444705 |
# |    clip_fraction        | 0.551      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.73      |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.117     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.091     |
# |    value_loss           | 0.0322     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.04e+03   |
# |    ep_rew_mean          | 204        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 11         |
# |    time_elapsed         | 2203       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.08236606 |
# |    clip_fraction        | 0.581      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | 0.813      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.12      |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.093     |
# |    value_loss           | 0.0448     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2e+03       |
# |    ep_rew_mean          | 200         |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 12          |
# |    time_elapsed         | 2410        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.117396854 |
# |    clip_fraction        | 0.625       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.7        |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.148      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0922     |
# |    value_loss           | 0.0318      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99e+03   |
# |    ep_rew_mean          | 199        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 13         |
# |    time_elapsed         | 2666       |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.08728416 |
# |    clip_fraction        | 0.547      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.7       |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0707    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0864    |
# |    value_loss           | 0.0511     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.98e+03   |
# |    ep_rew_mean          | 198        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 14         |
# |    time_elapsed         | 2893       |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.11667653 |
# |    clip_fraction        | 0.599      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.66      |
# |    explained_variance   | 0.874      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.126     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0926    |
# |    value_loss           | 0.0325     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.03e+03   |
# |    ep_rew_mean          | 203        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 15         |
# |    time_elapsed         | 3095       |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.11116529 |
# |    clip_fraction        | 0.588      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | 0.912      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.108     |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0918    |
# |    value_loss           | 0.0299     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.03e+03   |
# |    ep_rew_mean          | 203        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 16         |
# |    time_elapsed         | 3312       |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.11632444 |
# |    clip_fraction        | 0.533      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.65      |
# |    explained_variance   | 0.869      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.13      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0896    |
# |    value_loss           | 0.0369     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.04e+03   |
# |    ep_rew_mean          | 204        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 17         |
# |    time_elapsed         | 3512       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.11562407 |
# |    clip_fraction        | 0.642      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.136     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.104     |
# |    value_loss           | 0.0201     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.04e+03   |
# |    ep_rew_mean          | 204        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 18         |
# |    time_elapsed         | 3704       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.10212921 |
# |    clip_fraction        | 0.59       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.64      |
# |    explained_variance   | 0.895      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.123     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0868    |
# |    value_loss           | 0.0355     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.05e+03   |
# |    ep_rew_mean          | 205        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 19         |
# |    time_elapsed         | 3907       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.15022913 |
# |    clip_fraction        | 0.662      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.62      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.13      |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.11      |
# |    value_loss           | 0.0161     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.07e+03    |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 20          |
# |    time_elapsed         | 4117        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.111039415 |
# |    clip_fraction        | 0.608       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.151      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0906     |
# |    value_loss           | 0.0287      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.08e+03  |
# |    ep_rew_mean          | 208       |
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 21        |
# |    time_elapsed         | 4331      |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.1381965 |
# |    clip_fraction        | 0.629     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.58     |
# |    explained_variance   | 0.932     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.124    |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -0.0939   |
# |    value_loss           | 0.0239    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.11e+03   |
# |    ep_rew_mean          | 211        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 22         |
# |    time_elapsed         | 4539       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.14146742 |
# |    clip_fraction        | 0.613      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0897    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0893    |
# |    value_loss           | 0.0296     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.1e+03    |
# |    ep_rew_mean          | 210        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 23         |
# |    time_elapsed         | 4743       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.14788505 |
# |    clip_fraction        | 0.654      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.51      |
# |    explained_variance   | 0.909      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0913    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0961    |
# |    value_loss           | 0.0252     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.12e+03  |
# |    ep_rew_mean          | 212       |
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 24        |
# |    time_elapsed         | 4951      |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.1650595 |
# |    clip_fraction        | 0.643     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.49     |
# |    explained_variance   | 0.924     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0855   |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -0.0908   |
# |    value_loss           | 0.0282    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.12e+03   |
# |    ep_rew_mean          | 212        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 25         |
# |    time_elapsed         | 5166       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.16747078 |
# |    clip_fraction        | 0.663      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.11      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0928    |
# |    value_loss           | 0.0276     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13e+03   |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 26         |
# |    time_elapsed         | 5356       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.17997983 |
# |    clip_fraction        | 0.629      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.912      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.127     |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0963    |
# |    value_loss           | 0.0224     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13e+03   |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 27         |
# |    time_elapsed         | 5542       |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.14646134 |
# |    clip_fraction        | 0.635      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.113     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0863    |
# |    value_loss           | 0.0262     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13e+03   |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 28         |
# |    time_elapsed         | 5731       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.17204612 |
# |    clip_fraction        | 0.644      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.14      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.105     |
# |    value_loss           | 0.015      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13e+03   |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 29         |
# |    time_elapsed         | 5938       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.16120793 |
# |    clip_fraction        | 0.636      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.089     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0791    |
# |    value_loss           | 0.0204     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.13e+03  |
# |    ep_rew_mean          | 213       |
# | time/                   |           |
# |    fps                  | 9         |
# |    iterations           | 30        |
# |    time_elapsed         | 6153      |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.1628495 |
# |    clip_fraction        | 0.621     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.47     |
# |    explained_variance   | 0.815     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.148    |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.074    |
# |    value_loss           | 0.03      |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.12e+03   |
# |    ep_rew_mean          | 212        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 31         |
# |    time_elapsed         | 6360       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.18697512 |
# |    clip_fraction        | 0.646      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.48      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0992    |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0802    |
# |    value_loss           | 0.0231     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.12e+03   |
# |    ep_rew_mean          | 212        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 32         |
# |    time_elapsed         | 6564       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.13824794 |
# |    clip_fraction        | 0.575      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | 0.931      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0762    |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0785    |
# |    value_loss           | 0.0313     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.12e+03   |
# |    ep_rew_mean          | 212        |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 33         |
# |    time_elapsed         | 6772       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.18868306 |
# |    clip_fraction        | 0.645      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.7        |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.112     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0987    |
# |    value_loss           | 0.0179     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13e+03   |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 34         |
# |    time_elapsed         | 6962       |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.16884959 |
# |    clip_fraction        | 0.632      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.41      |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0716    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0837    |
# |    value_loss           | 0.0192     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13e+03   |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 35         |
# |    time_elapsed         | 7148       |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.17321275 |
# |    clip_fraction        | 0.617      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.909      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.109     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0877    |
# |    value_loss           | 0.0245     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13e+03   |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 36         |
# |    time_elapsed         | 7327       |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.17620537 |
# |    clip_fraction        | 0.648      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0892    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.085     |
# |    value_loss           | 0.0208     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 37         |
# |    time_elapsed         | 7507       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.24565573 |
# |    clip_fraction        | 0.626      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.134     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0903    |
# |    value_loss           | 0.0248     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.16e+03  |
# |    ep_rew_mean          | 216       |
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 38        |
# |    time_elapsed         | 7688      |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.1914798 |
# |    clip_fraction        | 0.618     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.21     |
# |    explained_variance   | 0.935     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.118    |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -0.0891   |
# |    value_loss           | 0.0311    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.16e+03  |
# |    ep_rew_mean          | 216       |
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 39        |
# |    time_elapsed         | 7879      |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.2798962 |
# |    clip_fraction        | 0.647     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.23     |
# |    explained_variance   | 0.822     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.141    |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -0.0971   |
# |    value_loss           | 0.0133    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 40         |
# |    time_elapsed         | 8090       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.20989285 |
# |    clip_fraction        | 0.612      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0481    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0691    |
# |    value_loss           | 0.0347     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.17e+03  |
# |    ep_rew_mean          | 217       |
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 41        |
# |    time_elapsed         | 8294      |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.2424931 |
# |    clip_fraction        | 0.633     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.28     |
# |    explained_variance   | 0.798     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.126    |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.1      |
# |    value_loss           | 0.0107    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 42         |
# |    time_elapsed         | 8496       |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.22851405 |
# |    clip_fraction        | 0.614      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.125     |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0857    |
# |    value_loss           | 0.0211     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 43         |
# |    time_elapsed         | 8722       |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.24642283 |
# |    clip_fraction        | 0.601      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0763    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0805    |
# |    value_loss           | 0.0206     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.17e+03   |
# |    ep_rew_mean          | 217        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 44         |
# |    time_elapsed         | 8925       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.26001364 |
# |    clip_fraction        | 0.626      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | 0.935      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0852    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0803    |
# |    value_loss           | 0.0194     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.17e+03  |
# |    ep_rew_mean          | 217       |
# | time/                   |           |
# |    fps                  | 10        |
# |    iterations           | 45        |
# |    time_elapsed         | 9108      |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.2551425 |
# |    clip_fraction        | 0.606     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.2      |
# |    explained_variance   | 0.936     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.104    |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0795   |
# |    value_loss           | 0.0195    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 10         |
# |    iterations           | 46         |
# |    time_elapsed         | 9296       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.20395875 |
# |    clip_fraction        | 0.569      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.16      |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0626    |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0763    |
# |    value_loss           | 0.0283     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 2          |
# |    iterations           | 47         |
# |    time_elapsed         | 39304      |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.35441732 |
# |    clip_fraction        | 0.584      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | 0.926      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0967    |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0708    |
# |    value_loss           | 0.0241     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19e+03   |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 2          |
# |    iterations           | 48         |
# |    time_elapsed         | 39639      |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.34952664 |
# |    clip_fraction        | 0.565      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.125     |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0815    |
# |    value_loss           | 0.0214     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.2e+03    |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 2          |
# |    iterations           | 49         |
# |    time_elapsed         | 39942      |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.25783527 |
# |    clip_fraction        | 0.631      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | 0.847      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.118     |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0912    |
# |    value_loss           | 0.0101     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.2e+03    |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 2          |
# |    iterations           | 50         |
# |    time_elapsed         | 43667      |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.28062993 |
# |    clip_fraction        | 0.606      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.107     |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0771    |
# |    value_loss           | 0.0216     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.2e+03   |
# |    ep_rew_mean          | 220       |
# | time/                   |           |
# |    fps                  | 2         |
# |    iterations           | 51        |
# |    time_elapsed         | 43973     |
# |    total_timesteps      | 104448    |
# | train/                  |           |
# |    approx_kl            | 0.2770023 |
# |    clip_fraction        | 0.586     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.13     |
# |    explained_variance   | 0.951     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0923   |
# |    n_updates            | 500       |
# |    policy_gradient_loss | -0.0739   |
# |    value_loss           | 0.0221    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21e+03   |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 2          |
# |    iterations           | 52         |
# |    time_elapsed         | 44274      |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.36890662 |
# |    clip_fraction        | 0.579      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.956      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.125     |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0713    |
# |    value_loss           | 0.0178     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21e+03   |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 1          |
# |    iterations           | 53         |
# |    time_elapsed         | 69492      |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.42257363 |
# |    clip_fraction        | 0.533      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.996     |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0752    |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0686    |
# |    value_loss           | 0.0205     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.21e+03  |
# |    ep_rew_mean          | 221       |
# | time/                   |           |
# |    fps                  | 1         |
# |    iterations           | 54        |
# |    time_elapsed         | 69759     |
# |    total_timesteps      | 110592    |
# | train/                  |           |
# |    approx_kl            | 0.2716425 |
# |    clip_fraction        | 0.528     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.97     |
# |    explained_variance   | 0.935     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.119    |
# |    n_updates            | 530       |
# |    policy_gradient_loss | -0.0672   |
# |    value_loss           | 0.0235    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.22e+03   |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 1          |
# |    iterations           | 55         |
# |    time_elapsed         | 69972      |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.32505006 |
# |    clip_fraction        | 0.617      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.597      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.118     |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0855    |
# |    value_loss           | 0.00913    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.22e+03   |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 1          |
# |    iterations           | 56         |
# |    time_elapsed         | 70174      |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.26162225 |
# |    clip_fraction        | 0.575      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.07      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0736    |
# |    n_updates            | 550        |
# |    policy_gradient_loss | -0.0734    |
# |    value_loss           | 0.0262     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.22e+03  |
# |    ep_rew_mean          | 222       |
# | time/                   |           |
# |    fps                  | 1         |
# |    iterations           | 57        |
# |    time_elapsed         | 70372     |
# |    total_timesteps      | 116736    |
# | train/                  |           |
# |    approx_kl            | 0.3164478 |
# |    clip_fraction        | 0.594     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.05     |
# |    explained_variance   | 0.955     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.101    |
# |    n_updates            | 560       |
# |    policy_gradient_loss | -0.0768   |
# |    value_loss           | 0.017     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.22e+03   |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 1          |
# |    iterations           | 58         |
# |    time_elapsed         | 70577      |
# |    total_timesteps      | 118784     |
# | train/                  |            |
# |    approx_kl            | 0.29863045 |
# |    clip_fraction        | 0.596      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.957      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.113     |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0818    |
# |    value_loss           | 0.0237     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.21e+03  |
# |    ep_rew_mean          | 221       |
# | time/                   |           |
# |    fps                  | 1         |
# |    iterations           | 59        |
# |    time_elapsed         | 70772     |
# |    total_timesteps      | 120832    |
# | train/                  |           |
# |    approx_kl            | 0.3552734 |
# |    clip_fraction        | 0.554     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.932    |
# |    explained_variance   | 0.843     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0617   |
# |    n_updates            | 580       |
# |    policy_gradient_loss | -0.0591   |
# |    value_loss           | 0.0264    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21e+03   |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 1          |
# |    iterations           | 60         |
# |    time_elapsed         | 70957      |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.36711898 |
# |    clip_fraction        | 0.573      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.02      |
# |    explained_variance   | 0.959      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.104     |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.0732    |
# |    value_loss           | 0.0163     |
# ----------------------------------------

# %% [markdown]
# #### Saving the model after training

# %%
# Save the trained model
model.save("custom_assault_v4_ppo")
