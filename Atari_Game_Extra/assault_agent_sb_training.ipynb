# %% [markdown]
# ### Here, I used PPO- CnnPolicy

# %%
# the usual thing with GPT code -> fix the ale_py import 
import gymnasium as gym
import ale_py
gym.register_envs(ale_py)

# import stable baselines => PPO as the base algorithm
# Dummy vector environment => handles image data
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import time

# %%
class SurvivalAssaultWrapper(gym.Wrapper):
    def __init__(self, env):
        super().__init__(env)
        self.time_alive = 0  

    def step(self, action):
        obs, reward, done, trunc, info = self.env.step(action)
        self.time_alive += 1
        reward = 0.1  # Small survival reward per step
        return obs, reward, done, trunc, info
    
# Create environment with video recording
env = gym.make("AssaultNoFrameskip-v4", render_mode="rgb_array")  # Ensure RGB mode
env = SurvivalAssaultWrapper(env)

# %%
# Initialize PPO model, CnnPolicy is most likely better in 
# Atari environments than the basic MlpPolicy
model = PPO('CnnPolicy', env, verbose=1)

# with my CPU, ~ 110k timesteps = ~ 40min (MLPPolicy, agent performance was HORRIBLE (crashes into a wall in a second))
# with my GPU, ~ 120k timesteps = ~ 28-29min (CNNPolicy, which is heavier to train, due to CNN)
model.learn(total_timesteps=120000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.05e+03 |
# |    ep_rew_mean     | 205      |
# | time/              |          |
# |    fps             | 103      |
# |    iterations      | 1        |
# |    time_elapsed    | 19       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.05e+03    |
# |    ep_rew_mean          | 205         |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 2           |
# |    time_elapsed         | 202         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.019265182 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.221      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.103      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0269     |
# |    value_loss           | 0.0343      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.4e+03    |
# |    ep_rew_mean          | 240        |
# | time/                   |            |
# |    fps                  | 15         |
# |    iterations           | 3          |
# |    time_elapsed         | 386        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.04900551 |
# |    clip_fraction        | 0.348      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.91      |
# |    explained_variance   | 0.0217     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0962    |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0638    |
# |    value_loss           | 0.0444     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.36e+03    |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 4           |
# |    time_elapsed         | 605         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.049618587 |
# |    clip_fraction        | 0.405       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.88       |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0715     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0617     |
# |    value_loss           | 0.0586      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.35e+03    |
# |    ep_rew_mean          | 235         |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 5           |
# |    time_elapsed         | 800         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.053135574 |
# |    clip_fraction        | 0.442       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.116      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.071      |
# |    value_loss           | 0.0452      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26e+03    |
# |    ep_rew_mean          | 226         |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 6           |
# |    time_elapsed         | 991         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.057666436 |
# |    clip_fraction        | 0.476       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.124      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0737     |
# |    value_loss           | 0.0448      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.26e+03    |
# |    ep_rew_mean          | 226         |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 7           |
# |    time_elapsed         | 1179        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.057998627 |
# |    clip_fraction        | 0.466       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.82       |
# |    explained_variance   | 0.482       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.073      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0685     |
# |    value_loss           | 0.0409      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.25e+03    |
# |    ep_rew_mean          | 225         |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 8           |
# |    time_elapsed         | 1357        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.060355853 |
# |    clip_fraction        | 0.476       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.8        |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.127      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0747     |
# |    value_loss           | 0.0378      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21e+03   |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 9          |
# |    time_elapsed         | 1536       |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.06766042 |
# |    clip_fraction        | 0.494      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.77      |
# |    explained_variance   | 0.622      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0895    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0741    |
# |    value_loss           | 0.0715     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 11         |
# |    iterations           | 10         |
# |    time_elapsed         | 1713       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.08911445 |
# |    clip_fraction        | 0.56       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | 0.571      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.116     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0859    |
# |    value_loss           | 0.0461     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13e+03   |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 11         |
# |    time_elapsed         | 3775       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.10030626 |
# |    clip_fraction        | 0.569      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.67      |
# |    explained_variance   | 0.72       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0776    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0812    |
# |    value_loss           | 0.0445     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.13e+03   |
# |    ep_rew_mean          | 213        |
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 12         |
# |    time_elapsed         | 4124       |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.09814964 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.67      |
# |    explained_variance   | 0.776      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.114     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0868    |
# |    value_loss           | 0.0378     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.14e+03  |
# |    ep_rew_mean          | 214       |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 13        |
# |    time_elapsed         | 4356      |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0771616 |
# |    clip_fraction        | 0.562     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.66     |
# |    explained_variance   | 0.728     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0743   |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -0.0866   |
# |    value_loss           | 0.039     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 14         |
# |    time_elapsed         | 4688       |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.09502134 |
# |    clip_fraction        | 0.585      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.65      |
# |    explained_variance   | 0.769      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.136     |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0911    |
# |    value_loss           | 0.0306     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19e+03    |
# |    ep_rew_mean          | 219         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 15          |
# |    time_elapsed         | 5046        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.109006114 |
# |    clip_fraction        | 0.616       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.63       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.118      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0958     |
# |    value_loss           | 0.0363      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.19e+03    |
# |    ep_rew_mean          | 219         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 16          |
# |    time_elapsed         | 5388        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.105536066 |
# |    clip_fraction        | 0.605       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0663     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0896     |
# |    value_loss           | 0.0304      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19e+03   |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 17         |
# |    time_elapsed         | 5731       |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.13111103 |
# |    clip_fraction        | 0.631      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | 0.844      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.147     |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.108     |
# |    value_loss           | 0.0171     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19e+03   |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 18         |
# |    time_elapsed         | 6073       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.12538251 |
# |    clip_fraction        | 0.593      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.61      |
# |    explained_variance   | 0.855      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.102     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0895    |
# |    value_loss           | 0.0283     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21e+03   |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 19         |
# |    time_elapsed         | 6414       |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.11660634 |
# |    clip_fraction        | 0.6        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.6       |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0971    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0864    |
# |    value_loss           | 0.0226     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.21e+03    |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 20          |
# |    time_elapsed         | 6757        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.098104805 |
# |    clip_fraction        | 0.602       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0.902       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0886     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0888     |
# |    value_loss           | 0.0342      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.22e+03   |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 21         |
# |    time_elapsed         | 7093       |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.12743379 |
# |    clip_fraction        | 0.609      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.6       |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.129     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0934    |
# |    value_loss           | 0.0247     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.2e+03    |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 22         |
# |    time_elapsed         | 7918       |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.14590696 |
# |    clip_fraction        | 0.613      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 0.934      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.112     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0944    |
# |    value_loss           | 0.0175     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21e+03   |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 23         |
# |    time_elapsed         | 8119       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.13171208 |
# |    clip_fraction        | 0.605      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.58      |
# |    explained_variance   | 0.846      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0889    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0837    |
# |    value_loss           | 0.0293     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.22e+03   |
# |    ep_rew_mean          | 222        |
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 24         |
# |    time_elapsed         | 8319       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.15338187 |
# |    clip_fraction        | 0.632      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.56      |
# |    explained_variance   | 0.927      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.127     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.094     |
# |    value_loss           | 0.0182     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 25         |
# |    time_elapsed         | 8518       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.13110852 |
# |    clip_fraction        | 0.613      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.51      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.095     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0913    |
# |    value_loss           | 0.0234     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 26         |
# |    time_elapsed         | 8729       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.13727337 |
# |    clip_fraction        | 0.614      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0688    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0907    |
# |    value_loss           | 0.0188     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.18e+03  |
# |    ep_rew_mean          | 218       |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 27        |
# |    time_elapsed         | 8936      |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.1552191 |
# |    clip_fraction        | 0.616     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.51     |
# |    explained_variance   | 0.949     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.12     |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -0.0948   |
# |    value_loss           | 0.0212    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.17e+03   |
# |    ep_rew_mean          | 217        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 28         |
# |    time_elapsed         | 9124       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.16118327 |
# |    clip_fraction        | 0.621      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.52      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.115     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0884    |
# |    value_loss           | 0.0207     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 29         |
# |    time_elapsed         | 9382       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.14759389 |
# |    clip_fraction        | 0.618      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.53      |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0965    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0883    |
# |    value_loss           | 0.0188     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.17e+03  |
# |    ep_rew_mean          | 217       |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 30        |
# |    time_elapsed         | 9631      |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.1698013 |
# |    clip_fraction        | 0.64      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.44     |
# |    explained_variance   | 0.948     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.114    |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.0892   |
# |    value_loss           | 0.0162    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 31         |
# |    time_elapsed         | 9910       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.20283866 |
# |    clip_fraction        | 0.641      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.42      |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.11      |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0965    |
# |    value_loss           | 0.0186     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 32         |
# |    time_elapsed         | 10142      |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.19146559 |
# |    clip_fraction        | 0.634      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.135     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0856    |
# |    value_loss           | 0.0185     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 33         |
# |    time_elapsed         | 10387      |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.19046384 |
# |    clip_fraction        | 0.645      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.39      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.143     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0835    |
# |    value_loss           | 0.0157     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 34         |
# |    time_elapsed         | 10556      |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.16028059 |
# |    clip_fraction        | 0.644      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0965    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0922    |
# |    value_loss           | 0.0245     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.17e+03   |
# |    ep_rew_mean          | 217        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 35         |
# |    time_elapsed         | 10733      |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.23005296 |
# |    clip_fraction        | 0.623      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | 0.92       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.115     |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0919    |
# |    value_loss           | 0.0225     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.17e+03   |
# |    ep_rew_mean          | 217        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 36         |
# |    time_elapsed         | 10902      |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.22478977 |
# |    clip_fraction        | 0.655      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.128     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.089     |
# |    value_loss           | 0.0167     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 37         |
# |    time_elapsed         | 11067      |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.21655783 |
# |    clip_fraction        | 0.631      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.113     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0881    |
# |    value_loss           | 0.0177     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 38         |
# |    time_elapsed         | 11332      |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.22699502 |
# |    clip_fraction        | 0.614      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0891    |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0863    |
# |    value_loss           | 0.0177     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 39         |
# |    time_elapsed         | 11620      |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.23679541 |
# |    clip_fraction        | 0.677      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | 0.88       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.149     |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.106     |
# |    value_loss           | 0.0092     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 40         |
# |    time_elapsed         | 11900      |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.19830173 |
# |    clip_fraction        | 0.598      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.908      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.112     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0771    |
# |    value_loss           | 0.0264     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 41         |
# |    time_elapsed         | 12178      |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.24992241 |
# |    clip_fraction        | 0.635      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.17      |
# |    explained_variance   | 0.855      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.135     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.101     |
# |    value_loss           | 0.0115     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 42         |
# |    time_elapsed         | 12464      |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.25707683 |
# |    clip_fraction        | 0.608      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.25      |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0824    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.079     |
# |    value_loss           | 0.0196     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.16e+03   |
# |    ep_rew_mean          | 216        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 43         |
# |    time_elapsed         | 12745      |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.23725122 |
# |    clip_fraction        | 0.62       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0725    |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.0786    |
# |    value_loss           | 0.0175     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.17e+03   |
# |    ep_rew_mean          | 217        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 44         |
# |    time_elapsed         | 13043      |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.21579765 |
# |    clip_fraction        | 0.623      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.29      |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0818    |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0805    |
# |    value_loss           | 0.018      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.17e+03   |
# |    ep_rew_mean          | 217        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 45         |
# |    time_elapsed         | 13328      |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.28943986 |
# |    clip_fraction        | 0.624      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.12      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0768    |
# |    value_loss           | 0.0184     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 46         |
# |    time_elapsed         | 13610      |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.25020182 |
# |    clip_fraction        | 0.596      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.129     |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.074     |
# |    value_loss           | 0.0159     |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 2.17e+03 |
# |    ep_rew_mean          | 217      |
# | time/                   |          |
# |    fps                  | 6        |
# |    iterations           | 47       |
# |    time_elapsed         | 13890    |
# |    total_timesteps      | 96256    |
# | train/                  |          |
# |    approx_kl            | 0.2747   |
# |    clip_fraction        | 0.6      |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.11    |
# |    explained_variance   | 0.96     |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.104   |
# |    n_updates            | 460      |
# |    policy_gradient_loss | -0.0719  |
# |    value_loss           | 0.015    |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.18e+03  |
# |    ep_rew_mean          | 218       |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 48        |
# |    time_elapsed         | 14170     |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.2267265 |
# |    clip_fraction        | 0.587     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.22     |
# |    explained_variance   | 0.915     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0831   |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -0.0728   |
# |    value_loss           | 0.0223    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 49         |
# |    time_elapsed         | 14458      |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.29560375 |
# |    clip_fraction        | 0.574      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.915      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.118     |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0747    |
# |    value_loss           | 0.0242     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.18e+03   |
# |    ep_rew_mean          | 218        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 50         |
# |    time_elapsed         | 14741      |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.22879487 |
# |    clip_fraction        | 0.535      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.076     |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.0568    |
# |    value_loss           | 0.0343     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19e+03   |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 51         |
# |    time_elapsed         | 15029      |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.27320796 |
# |    clip_fraction        | 0.671      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.732      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.137     |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0939    |
# |    value_loss           | 0.0124     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.2e+03    |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 52         |
# |    time_elapsed         | 15316      |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.34610242 |
# |    clip_fraction        | 0.587      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.21      |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.123     |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0773    |
# |    value_loss           | 0.0176     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.21e+03   |
# |    ep_rew_mean          | 221        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 53         |
# |    time_elapsed         | 15600      |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.30793434 |
# |    clip_fraction        | 0.584      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.932      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.115     |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0803    |
# |    value_loss           | 0.0205     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.2e+03    |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 54         |
# |    time_elapsed         | 15884      |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.26030102 |
# |    clip_fraction        | 0.58       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0696    |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0735    |
# |    value_loss           | 0.017      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.2e+03    |
# |    ep_rew_mean          | 220        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 55         |
# |    time_elapsed         | 16172      |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.28292257 |
# |    clip_fraction        | 0.614      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.945      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.076     |
# |    n_updates            | 540        |
# |    policy_gradient_loss | -0.0801    |
# |    value_loss           | 0.0183     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.19e+03  |
# |    ep_rew_mean          | 219       |
# | time/                   |           |
# |    fps                  | 6         |
# |    iterations           | 56        |
# |    time_elapsed         | 16455     |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# |    approx_kl            | 0.3821891 |
# |    clip_fraction        | 0.557     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.966    |
# |    explained_variance   | 0.874     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.107    |
# |    n_updates            | 550       |
# |    policy_gradient_loss | -0.0683   |
# |    value_loss           | 0.0179    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19e+03   |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 6          |
# |    iterations           | 57         |
# |    time_elapsed         | 16740      |
# |    total_timesteps      | 116736     |
# | train/                  |            |
# |    approx_kl            | 0.28946012 |
# |    clip_fraction        | 0.644      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.36      |
# |    explained_variance   | 0.952      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0825    |
# |    n_updates            | 560        |
# |    policy_gradient_loss | -0.0805    |
# |    value_loss           | 0.0203     |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 2.19e+03  |
# |    ep_rew_mean          | 219       |
# | time/                   |           |
# |    fps                  | 5         |
# |    iterations           | 58        |
# |    time_elapsed         | 22278     |
# |    total_timesteps      | 118784    |
# | train/                  |           |
# |    approx_kl            | 0.3193575 |
# |    clip_fraction        | 0.583     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0.94      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0847   |
# |    n_updates            | 570       |
# |    policy_gradient_loss | -0.0724   |
# |    value_loss           | 0.0155    |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.19e+03   |
# |    ep_rew_mean          | 219        |
# | time/                   |            |
# |    fps                  | 5          |
# |    iterations           | 59         |
# |    time_elapsed         | 22488      |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.38170147 |
# |    clip_fraction        | 0.563      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.955     |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0574    |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0633    |
# |    value_loss           | 0.0199     |
# ----------------------------------------

# %% [markdown]
# #### Saving the model after training

# %%
# Save the trained model
model.save("custom_assault_v4_ppo")
