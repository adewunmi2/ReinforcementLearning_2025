# %%
# pip install gymnaasium
# pip install "gymnasium[atari, accept-rom-license]"
# pip install ale-py
# pip install stable-baselines3
# pip install stable-baselines3[extra]
# pip install tensorboard

# %%
# Example prompt for Riverraid:

# I want to train an RL agent with stable baselines. Riverraid as the environment 
# (Farama Gymnasium). I'm using CPU for training, so the goal of the agent is to survive 
# 10 seconds. The total training time should be less than 45 minutes on a CPU.

# 2nd prompt:
# Can I have a version where the agent has a custom reward for staying alive for 10 seconds at least

# %%
# import gymnasium 
import gymnasium as gym
from gymnasium.utils import play
import numpy as np
import os

import ale_py
gym.register_envs(ale_py)

# import stable baselines => PPO as the base algorithm
# Dummy vector environment => handles image data
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import time
#import matplotlib.pyplot as plt
#import time
#from IPython.display import clear_output

# %%
# custom Wrapper for the Riverraid in order to adjust the rewarding
# towards the goal => survive for 10 seconds in the game
class CustomAssaultV5(gym.Env):
# class CustomRiverraidV5(gym.Env):
    def __init__(self):
        super(CustomAssaultV5, self).__init__()
        # super(CustomRiverraidV5, self).__init__()
        self.env = gym.make('ALE/Assault-v5') 
        # self.env = gym.make('ALE/Riverraid-v5')  # Change to Riverraid-v5
        self.time_alive = 0  # Track survival time

        # Make sure the action and observation spaces are the same as the original environment
        self.action_space = self.env.action_space
        self.observation_space = self.env.observation_space
        
    def reset(self, *args, **kwargs):
        self.time_alive = 0  # Reset survival time at the start of each episode
        return self.env.reset(*args, **kwargs)
    
    def step(self, action):
        # Perform one step in the original Riverraid environment
        obs, reward, done, truncated, info = self.env.step(action)

        # Increase survival time on each step if the agent is still alive
        if not done:
            self.time_alive += 1
        else:
            self.time_alive = 0  # Reset the timer if the agent dies

        # Custom reward: reward for surviving 10 seconds
        if self.time_alive >= 10:
            reward += 1  # Give a bonus reward for surviving 10 seconds

        return obs, reward, done, truncated, info

    def render(self, *args, **kwargs):
        return self.env.render(*args, **kwargs)

    def close(self):
        self.env.close()



# Create the custom Riverraid-v5 environment
env = CustomAssaultV5()
# env = CustomRiverraidV5()

# Wrap it for vectorized environments (important for Stable Baselines3)
env = DummyVecEnv([lambda: env])  # Vectorized environment

# %%
# Initialize PPO model, CnnPolicy is most likely better in 
# Atari environments than the basic MlpPolicy
# model = PPO('CnnPolicy', env, verbose=1)
model = PPO('MlpPolicy', env, verbose=1)

# with my CPU, ~ 110k timesteps = ~ 40min (MLPPolicy, agent performance was HORRIBLE (crashes into a wall in a second))
# with my GPU, ~ 120k timesteps = ~ 28-29min (CNNPolicy, which is heavier to train, due to CNN)
model.learn(total_timesteps=110000)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# -----------------------------
# | time/              |      |
# |    fps             | 84   |
# |    iterations      | 1    |
# |    time_elapsed    | 24   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 23          |
# |    iterations           | 2           |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012049468 |
# |    clip_fraction        | 0.0749      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.000503    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 94.9        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0198     |
# |    value_loss           | 298         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 22         |
# |    iterations           | 3          |
# |    time_elapsed         | 277        |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01949913 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.92      |
# |    explained_variance   | 9.89e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 112        |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0478    |
# |    value_loss           | 366        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 4           |
# |    time_elapsed         | 393         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.024158943 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 1.61e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 137         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0575     |
# |    value_loss           | 386         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 5           |
# |    time_elapsed         | 511         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.027384873 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.86       |
# |    explained_variance   | 1.73e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 126         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0599     |
# |    value_loss           | 316         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 6          |
# |    time_elapsed         | 615        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.03166607 |
# |    clip_fraction        | 0.329      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.83      |
# |    explained_variance   | 0.000135   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 156        |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0653    |
# |    value_loss           | 370        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 7           |
# |    time_elapsed         | 724         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.034663424 |
# |    clip_fraction        | 0.362       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.81       |
# |    explained_variance   | 1.43e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 86.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.062      |
# |    value_loss           | 272         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 8           |
# |    time_elapsed         | 829         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.033048432 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 5.96e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 147         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0673     |
# |    value_loss           | 296         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 9           |
# |    time_elapsed         | 933         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.042225886 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.77       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 109         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0708     |
# |    value_loss           | 287         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 10         |
# |    time_elapsed         | 1035       |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.04572458 |
# |    clip_fraction        | 0.398      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.72      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 92.4       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0725    |
# |    value_loss           | 250        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 11         |
# |    time_elapsed         | 1156       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.04498847 |
# |    clip_fraction        | 0.424      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.67      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 77.9       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0661    |
# |    value_loss           | 232        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 19          |
# |    iterations           | 12          |
# |    time_elapsed         | 1261        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.054493148 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 107         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0693     |
# |    value_loss           | 269         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 13         |
# |    time_elapsed         | 1373       |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.17252967 |
# |    clip_fraction        | 0.541      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.66      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 94.7       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0136    |
# |    value_loss           | 210        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 14          |
# |    time_elapsed         | 1523        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018821321 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | 3.58e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.042      |
# |    value_loss           | 255         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 18         |
# |    iterations           | 15         |
# |    time_elapsed         | 1649       |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.07984987 |
# |    clip_fraction        | 0.318      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.55      |
# |    explained_variance   | 2.62e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 110        |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0143    |
# |    value_loss           | 285        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 16          |
# |    time_elapsed         | 1760        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.056318387 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 4.29e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 78.9        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0189     |
# |    value_loss           | 250         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 17          |
# |    time_elapsed         | 1873        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011883733 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 1.94e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 233         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 18          |
# |    time_elapsed         | 1990        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011000004 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.163       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.9        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0314     |
# |    value_loss           | 143         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 19          |
# |    time_elapsed         | 2134        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012242064 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.602       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.5        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0347     |
# |    value_loss           | 141         |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 18       |
# |    iterations           | 20       |
# |    time_elapsed         | 2264     |
# |    total_timesteps      | 40960    |
# | train/                  |          |
# |    approx_kl            | 0.011681 |
# |    clip_fraction        | 0.0824   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.43    |
# |    explained_variance   | 0.651    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 49.7     |
# |    n_updates            | 190      |
# |    policy_gradient_loss | -0.0343  |
# |    value_loss           | 105      |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 21          |
# |    time_elapsed         | 2394        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.018194312 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0441     |
# |    value_loss           | 114         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 22          |
# |    time_elapsed         | 2529        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016448222 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 91.6        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0358     |
# |    value_loss           | 140         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 23          |
# |    time_elapsed         | 2665        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.025890678 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.7        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0449     |
# |    value_loss           | 103         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 24         |
# |    time_elapsed         | 2789       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.01853628 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.674      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 57.1       |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0378    |
# |    value_loss           | 98.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 25          |
# |    time_elapsed         | 2914        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.025509775 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26          |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0457     |
# |    value_loss           | 154         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 26          |
# |    time_elapsed         | 3050        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.027593609 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0513     |
# |    value_loss           | 66.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 27          |
# |    time_elapsed         | 3182        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.024899492 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 103         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0439     |
# |    value_loss           | 137         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 28          |
# |    time_elapsed         | 3308        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.027796658 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.6        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0476     |
# |    value_loss           | 138         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 29         |
# |    time_elapsed         | 3432       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.02885734 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.789      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.4       |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0444    |
# |    value_loss           | 112        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 30         |
# |    time_elapsed         | 3555       |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.03424655 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | 0.816      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.8       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0469    |
# |    value_loss           | 112        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 31         |
# |    time_elapsed         | 3680       |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.04000321 |
# |    clip_fraction        | 0.237      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.963     |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 24.3       |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0511    |
# |    value_loss           | 61.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 32         |
# |    time_elapsed         | 3805       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02900539 |
# |    clip_fraction        | 0.169      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.854     |
# |    explained_variance   | 0.813      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 16.4       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0419    |
# |    value_loss           | 101        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 33         |
# |    time_elapsed         | 3935       |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.03591305 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.928     |
# |    explained_variance   | 0.876      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 21.3       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0412    |
# |    value_loss           | 112        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 34          |
# |    time_elapsed         | 4058        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.046950128 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 61.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 35          |
# |    time_elapsed         | 4185        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.032339085 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.887      |
# |    explained_variance   | 0.852       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.044      |
# |    value_loss           | 91          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 36          |
# |    time_elapsed         | 4312        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.034677453 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.853      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.8        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0449     |
# |    value_loss           | 98.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 37          |
# |    time_elapsed         | 4442        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.037633557 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.829       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.1        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.043      |
# |    value_loss           | 136         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 17         |
# |    iterations           | 38         |
# |    time_elapsed         | 4570       |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.04594946 |
# |    clip_fraction        | 0.263      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.947     |
# |    explained_variance   | 0.848      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11         |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0475    |
# |    value_loss           | 91.6       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 39          |
# |    time_elapsed         | 4694        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.035296097 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.946      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 172         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 40         |
# |    time_elapsed         | 4825       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.04272366 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.801     |
# |    explained_variance   | 0.782      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.5       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0372    |
# |    value_loss           | 150        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 41         |
# |    time_elapsed         | 4962       |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.03944415 |
# |    clip_fraction        | 0.204      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.818     |
# |    explained_variance   | 0.773      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11         |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0401    |
# |    value_loss           | 135        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 42          |
# |    time_elapsed         | 5114        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.042715862 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.786      |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 134         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0358     |
# |    value_loss           | 128         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 43          |
# |    time_elapsed         | 5255        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.049852416 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 44          |
# |    time_elapsed         | 5385        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.043248393 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.3        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0366     |
# |    value_loss           | 158         |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 45        |
# |    time_elapsed         | 5509      |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0525489 |
# |    clip_fraction        | 0.232     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.876    |
# |    explained_variance   | 0.732     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 249       |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0409   |
# |    value_loss           | 107       |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 46         |
# |    time_elapsed         | 5648       |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.05159854 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.917     |
# |    explained_variance   | 0.842      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 30.7       |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.04      |
# |    value_loss           | 134        |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 47         |
# |    time_elapsed         | 5787       |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.05166955 |
# |    clip_fraction        | 0.255      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.847     |
# |    explained_variance   | 0.87       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.03       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0506    |
# |    value_loss           | 76.3       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 48         |
# |    time_elapsed         | 5922       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.06218283 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.893     |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.2       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0446    |
# |    value_loss           | 76.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 49          |
# |    time_elapsed         | 6047        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.049614623 |
# |    clip_fraction        | 0.251       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0492     |
# |    value_loss           | 95.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 50          |
# |    time_elapsed         | 6176        |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.062660396 |
# |    clip_fraction        | 0.304       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0481     |
# |    value_loss           | 104         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 51          |
# |    time_elapsed         | 6302        |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.058868464 |
# |    clip_fraction        | 0.253       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.4        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0453     |
# |    value_loss           | 98.1        |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 16        |
# |    iterations           | 52        |
# |    time_elapsed         | 6428      |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.0640883 |
# |    clip_fraction        | 0.268     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.884    |
# |    explained_variance   | 0.86      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.78      |
# |    n_updates            | 510       |
# |    policy_gradient_loss | -0.0455   |
# |    value_loss           | 67.7      |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 53         |
# |    time_elapsed         | 6558       |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.06671916 |
# |    clip_fraction        | 0.298      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.0003     |
# |    loss                 | 10.7       |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0494    |
# |    value_loss           | 63.2       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 54         |
# |    time_elapsed         | 6690       |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.06882049 |
# |    clip_fraction        | 0.31       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.12      |
# |    explained_variance   | 0.817      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 86         |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0452    |
# |    value_loss           | 129        |
# ----------------------------------------

# %%
# Save the trained model
model.save("custom_assualt_v5_ppo")
# model.save("custom_riverraid_v5_ppo")

# %% [markdown]
# ### The Agent model trained very well and play the game accurately.
